# %% [markdown]
# <a href="https://colab.research.google.com/github/pnspivey/For-Dummies-Python/blob/main/My_First_Collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello, Phoenix. This is your first collab using Google. You are learning this information from the Beginning Programming with Python for Dummies. ![74441754997__101D9C7C-561C-4B64-A40F-2BAF3C27E1CA.HEIC](data:image/heic;base64,...)
